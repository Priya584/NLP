# %%
import pandas as pd

# Load the parquet file
df = pd.read_parquet("tokenized_gujarati_sentences.parquet")

# Print schema / column names
print("Columns in dataset:", df.columns.tolist())

# Print first few rows
print("\nHead of dataset:")
print(len(df))

# If one of the columns contains tokenized words, check type
for col in df.columns:
    print(f"\nColumn: {col}")
    print(df[col].iloc[0])
    print("Type:", type(df[col].iloc[0]))
# Out:
# Columns in dataset: ['sentence']
#
# Head of dataset:
# 14811
#
# Column: sentence
# આ વીડિયો જુઓ : ઊંઝા માર્કેટયાર્ડ આજથી 25 જુલાઈ સુધી બંધ
# Type: <class 'str'>

# %%
import csv
import pandas as pd
from collections import Counter, defaultdict

# Load dataset
df = pd.read_parquet("tokenized_gujarati_sentences.parquet")

# Extract sentences
sentences = df["sentence"].tolist()

# --- Step 1: Tokenization ---
# For Gujarati, simple whitespace split works as a baseline
tokenized_sentences = [s.strip().split() for s in sentences]

# --- Step 2: Function to build n-gram models ---
def build_ngram_model(sentences, n):
    ngram_counts = Counter()
    context_counts = Counter()

    for tokens in sentences:
        tokens = ["<s>"] * (n-1) + tokens + ["</s>"]  # padding
        ngrams = [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

        ngram_counts.update(ngrams)

        if n > 1:
            contexts = [ng[:-1] for ng in ngrams]  # all (n-1)-grams
            context_counts.update(contexts)       # count every occurrence

    # Convert counts to probabilities
    model = defaultdict(dict)
    total_unigrams = sum(ngram_counts.values())

    for ngram, count in ngram_counts.items():
        if n == 1:
            model[()][ngram[0]] = count / total_unigrams
        else:
            context = ngram[:-1]
            word = ngram[-1]
            model[context][word] = count / context_counts[context]  # <-- Correct formula

    return model


# --- Step 3: Build models ---
unigram_model = build_ngram_model(tokenized_sentences, 1)
bigram_model = build_ngram_model(tokenized_sentences, 2)
trigram_model = build_ngram_model(tokenized_sentences, 3)
quadrigram_model = build_ngram_model(tokenized_sentences, 4)

# --- Step 4: Print samples ---

# Function to save n-gram model into CSV
def save_ngram_to_csv(model, ngram_type, filename):
    with open(filename, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["Ngram_Type", "Context", "Word", "Probability"])

        for context, next_words in model.items():
            for word, prob in next_words.items():
                writer.writerow([ngram_type, " ".join(context), word, prob])


# Save each model separately
save_ngram_to_csv(unigram_model, "Unigram", "unigram_probs.csv")
save_ngram_to_csv(bigram_model, "Bigram", "bigram_probs.csv")
save_ngram_to_csv(trigram_model, "Trigram", "trigram_probs.csv")
save_ngram_to_csv(quadrigram_model, "Quadrigram", "quadrigram_probs.csv")

print("✅ All n-gram probabilities saved into CSV files successfully!")
# Out:
# ✅ All n-gram probabilities saved into CSV files successfully!

# %%
import pandas as pd
import random
from collections import Counter
import math

# reproducible sampling
random.seed(42)

# -------------------------------
# Load dataset
# -------------------------------
file_path = "/content/tokenized_gujarati_sentences.parquet"
df = pd.read_parquet(file_path)

# -------------------------------
# Ensure we have a tokens column (list of tokens per sentence)
# -------------------------------
if "tokens" not in df.columns:
    # split on whitespace; filter out empty tokens
    df["tokens"] = df["sentence"].astype(str).apply(lambda s: [t for t in s.split() if t.strip() != ""])

# list of token lists
sentences = df["tokens"].tolist()

# -------------------------------
# Take 1000 random sentences (or fewer if dataset smaller)
# -------------------------------
sample_sentences = random.sample(sentences, min(1000, len(sentences)))

# -------------------------------
# Build bigram (and unigram) counts using the FULL dataset
# -------------------------------
def build_bigram_counts(sentences_list):
    unigram_counts = Counter()
    bigram_counts = Counter()
    for sent in sentences_list:
        tokens = ["<s>"] + sent + ["</s>"]
        for i in range(len(tokens) - 1):
            unigram_counts[tokens[i]] += 1
            bigram_counts[(tokens[i], tokens[i+1])] += 1
        # add last token count (</s>)
        unigram_counts[tokens[-1]] += 1
    return unigram_counts, bigram_counts

unigram_counts, bigram_counts = build_bigram_counts(sentences)  # full data
V = len(unigram_counts)  # vocabulary size (number of token types)
total_tokens = sum(unigram_counts.values())

print("Vocabulary size (V):", V)
print("Total tokens:", total_tokens)

# -------------------------------
# Smoothing Functions
# -------------------------------
def add_one_prob(w1, w2):
    # Laplace (add-1)
    return (bigram_counts[(w1, w2)] + 1) / (unigram_counts[w1] + V)

def add_k_prob(w1, w2, k=0.5):
    # Add-k smoothing
    return (bigram_counts[(w1, w2)] + k) / (unigram_counts[w1] + k * V)

def add_type_prob(w1, w2):
    # Token-Type smoothing variant (may not sum to 1)
    return (bigram_counts[(w1, w2)] + 1) / (unigram_counts[w1] + len(bigram_counts))

# -------------------------------
# Sentence probability (log-sum for numeric stability)
# -------------------------------
def sentence_prob(sentence_tokens, method="add_one", k=0.5, tiny=1e-12):
    tokens = ["<s>"] + sentence_tokens + ["</s>"]
    log_prob = 0.0
    for i in range(len(tokens) - 1):
        w1, w2 = tokens[i], tokens[i + 1]
        if method == "add_one":
            prob = add_one_prob(w1, w2)
        elif method == "add_k":
            prob = add_k_prob(w1, w2, k)
        elif method == "add_type":
            prob = add_type_prob(w1, w2)
        else:
            raise ValueError("Unknown smoothing method: " + str(method))
        # avoid log(0)
        if prob <= 0:
            prob = tiny
        log_prob += math.log(prob)
    # return both log-prob and prob (prob may underflow to 0 for long sentences)
    return log_prob, math.exp(log_prob) if log_prob > -700 else 0.0

# -------------------------------
# Example: compute for first 5 sampled sentences
# -------------------------------
for sent in sample_sentences[:100]:
    sent_str = " ".join(sent)
    lp1, p1 = sentence_prob(sent, method="add_one")
    lpk, pk = sentence_prob(sent, method="add_k", k=0.5)
    lpt, pt = sentence_prob(sent, method="add_type")
    print("Sentence:", sent_str)
    print(" Add-One: log-prob =", lp1, ", prob =", p1)
    print(" Add-K  : log-prob =", lpk, ", prob =", pk)
    print(" Add-Type: log-prob =", lpt, ", prob =", pt)
    print("-" * 60)

# -------------------------------
# (Optional) Average log-prob or average prob over all sampled sentences
# -------------------------------
def avg_logprob_over_samples(samples, method="add_one", k=0.5):
    total_log = 0.0
    for s in samples:
        lp, _ = sentence_prob(s, method=method, k=k)
        total_log += lp
    return total_log / len(samples)

print("Average log-prob (Add-One) over sample:", avg_logprob_over_samples(sample_sentences, "add_one"))
print("Average log-prob (Add-K k=0.5) over sample:", avg_logprob_over_samples(sample_sentences, "add_k", k=0.5))
print("Average log-prob (Add-Type) over sample:", avg_logprob_over_samples(sample_sentences, "add_type"))
# Out:
# Vocabulary size (V): 40240
# Total tokens: 258501
# Sentence: જોબ કૌભાંડને લઈ હવે કૃષિ ભવનમાં પણ ફેક ઈન્ટરવ્યું !
#  Add-One: log-prob = -104.8519590444298 , prob = 2.906516349506758e-46
#  Add-K  : log-prob = -100.2980604562403 , prob = 2.7612504410973723e-44
#  Add-Type: log-prob = -119.32316112441916 , prob = 1.5087231714070694e-52
# ------------------------------------------------------------
# Sentence: આ દિવસ એ ગુરુ સ્મૃતિનો દિવસ છે .
#  Add-One: log-prob = -64.84997429051965 , prob = 6.855103465307023e-29
#  Add-K  : log-prob = -60.69384966860029 , prob = 4.3751807893637616e-27
#  Add-Type: log-prob = -76.27522629975766 , prob = 7.483247548781064e-34
# ------------------------------------------------------------
# Sentence: ભાજપે ૩ ટિકિટ માગણીદારો તથા એક MLAને પ્રવક્તા નીમતા ભારે આશ્ચર્ય
#  Add-One: log-prob = -118.86466095062664 , prob = 2.3863473347504386e-52
#  Add-K  : log-prob = -114.17397842898801 , prob = 2.5993884887097656e-50
#  Add-Type: log-prob = -134.68705798152365 , prob = 3.2074059819107316e-59
# ------------------------------------------------------------
# Sentence: તે પ્રકારનાં પોસ્ટકાર્ડ લખવામાં આવ્યાં છે .
#  Add-One: log-prob = -57.388977123868905 , prob = 1.1920210179334793e-25
#  Add-K  : log-prob = -53.71809912519832 , prob = 4.683019558390707e-24
#  Add-Type: log-prob = -67.51551962609274 , prob = 4.768506550453851e-30
# ------------------------------------------------------------
# Sentence: આજની તારીખે , છોકરી ઉછર્યા અને એક તોફાની વ્યક્તિગત જીવન સાથે એક વાસ્તવિક સુંદરતા ફેરવી .
#  Add-One: log-prob = -151.94563560963113 , prob = 1.0252951557580592e-66
#  Add-K  : log-prob = -144.23612756876508 , prob = 2.2858393558224233e-63
#  Add-Type: log-prob = -174.05027676152298 , prob = 2.5758776371936986e-76
# ------------------------------------------------------------
# Sentence: સામે એક WhatsApp બટન પણ છે , તેના પર ક્લિક કરવાથી તમારા ફોનમાં WhatsApp ચેટ ખુલશે અને તમે અહીંથી તમારું ભોજન બુક કરાવી શકો છો .
#  Add-One: log-prob = -232.46724973387666 , prob = 1.0983891072764979e-101
#  Add-K  : log-prob = -219.5993022928107 , prob = 4.258285585744086e-96
#  Add-Type: log-prob = -267.78015570053554 , prob = 5.0647267104432684e-117
# ------------------------------------------------------------
# Sentence: જે અન્વયે ડી .
#  Add-One: log-prob = -34.16425187964739 , prob = 1.4542997528588529e-15
#  Add-K  : log-prob = -31.62323115250814 , prob = 1.8458874220361038e-14
#  Add-Type: log-prob = -40.425284206073805 , prob = 2.7766563938752605e-18
# ------------------------------------------------------------
# Sentence: .
#  Add-One: log-prob = -6.251611601542329 , prob = 0.0019273455189633814
#  Add-K  : log-prob = -5.3273687919138935 , prob = 0.004856832551519934
#  Add-Type: log-prob = -8.50610138648829 , prob = 0.0002022307094124616
# ------------------------------------------------------------
# Sentence: તેમાં પ્રમુખ દ્વારા કરવામાં આવેલા ભ્રષ્ટાચારના આક્ષેપને તપાસી રહી છે .
#  Add-One: log-prob = -91.66120186781166 , prob = 1.5561298165727964e-40
#  Add-K  : log-prob = -85.84737808131439 , prob = 5.211436056653256e-38
#  Add-Type: log-prob = -107.12994814470615 , prob = 2.978891424229303e-47
# ------------------------------------------------------------
# Sentence: એચડીએફસીબેંકના શેરમાં આશરે પાંચ ટકાનો ઉછાળો રહ્યો હતો .
#  Add-One: log-prob = -80.14517655997332 , prob = 1.560961058663588e-35
#  Add-K  : log-prob = -75.35185769708312 , prob = 1.884100223112442e-33
#  Add-Type: log-prob = -93.09575517563476 , prob = 3.7070397131276903e-41
# ------------------------------------------------------------
# Sentence: ખેલાડીઓ માટે જિમ સાથેના ખાસ ડ્રેસિંગ રૂમ બનાવાયા .
#  Add-One: log-prob = -89.89217186042018 , prob = 9.12695259272279e-40
#  Add-K  : log-prob = -85.79894934924103 , prob = 5.470030457585333e-38
#  Add-Type: log-prob = -102.82725087411767 , prob = 2.2013665147751994e-45
# ------------------------------------------------------------
# Sentence: રાજકોટ મહાનગરપાલિકા દ્રારા રેસકોર્ષ રીગ રોડ ખાતે તા . ૦૨ ૧૧ ૨૧ થી ૦૬ ૧૧ ૨૧ સુધી યોજાયેલ રંગોલી સ્ પધામાં બહોળી સંખ્યામાં સહેરી નાગરીકો દ્રારા ઉત્સાહ પુર્વક ભાગ લીધેલં રંગોળી સ્ પધાનાં દિવસ-૫ દરમ્યાન આયોજનનાં સ્ થળે મહાનગરપાલિકાનાં કમિશનર ની સુચના તથા નાયબ કમિશનરનાં માર્ગદશન તથા નાયબ પોલિસ અધિક્ષક અને સુરક્ષા અધિકારી દ્રારા એસ .
#  Add-One: log-prob = -541.1041985590178 , prob = 1.003303739941621e-235
#  Add-K  : log-prob = -516.3920835857267 , prob = 5.417109322976679e-225
#  Add-Type: log-prob = -616.7227771578399 , prob = 1.4477748109421783e-268
# ------------------------------------------------------------
# Sentence: પાર્કિંગ ધોરણો માટે જરૂરી એડીએ માર્ગદર્શિકા
#  Add-One: log-prob = -67.71151966971631 , prob = 3.919770554621751e-30
#  Add-K  : log-prob = -64.90263687837977 , prob = 6.503437078459976e-29
#  Add-Type: log-prob = -76.83320185037502 , prob = 4.2831610986062375e-34
# ------------------------------------------------------------
# Sentence: મંગળવારે નિફ્ટીના તમામ સેક્ટરમાં હરિયાળી જોવા મળી હતી .
#  Add-One: log-prob = -77.60073694526741 , prob = 1.988053892022422e-34
#  Add-K  : log-prob = -72.76784394400167 , prob = 2.4964732397836164e-32
#  Add-Type: log-prob = -90.53722248677899 , prob = 4.788327727250266e-40
# ------------------------------------------------------------
# Sentence: તેમણે જે કહ્યું તે સત્ય છે , પરંતુ એ પણ તથ્ય છે કે આરોગ્ય ક્ષેત્ર માટે બજેટરી ફાળવણીનું સ્તર એનડીએ શાસન દરમિયાન પણ કોઈ જુદું નહોતું .
#  Add-One: log-prob = -241.67787174645562 , prob = 1.0980797998650413e-105
#  Add-K  : log-prob = -228.66777008238526 , prob = 4.907375203129751e-100
#  Add-Type: log-prob = -278.15836288248033 , prob = 1.5752805285764986e-121
# ------------------------------------------------------------
# Sentence: સરકારે ટેકાના ભાવે ખરીદેલી ડાંગરનો જથ્થો આ ગોડાઉનમાં રાખવામાં આવ્યો છે .
#  Add-One: log-prob = -105.75098343969282 , prob = 1.1828547992544697e-46
#  Add-K  : log-prob = -99.68835300327844 , prob = 5.080405536681597e-44
#  Add-Type: log-prob = -122.54490300221902 , prob = 6.01762112617895e-54
# ------------------------------------------------------------
# Sentence: કેટલાક રાજ્યોમાં દંડની રકમમાં ઘટાડો કરવામાં આવ્યો છે .
#  Add-One: log-prob = -72.68161381401214 , prob = 2.7212985155052736e-32
#  Add-K  : log-prob = -67.76920494354796 , prob = 3.700055598923682e-30
#  Add-Type: log-prob = -85.48782111012072 , prob = 7.466396030740487e-38
# ------------------------------------------------------------
# Sentence: તેમણે કહ્યું કે 2020 માં કોવિડ-19 મહામારીના કારણે તેને લાગુ કરી શકાયો ન હતો .
#  Add-One: log-prob = -128.4607863072694 , prob = 1.6225174108181403e-56
#  Add-K  : log-prob = -120.30173190562999 , prob = 5.670504115543678e-53
#  Add-Type: log-prob = -149.35480633519373 , prob = 1.367828860525265e-65
# ------------------------------------------------------------
# Sentence: ગુજરાત કેડરના 2008 બેન્ચના એસપી રેન્કના અધિકારી સારા રિઝવી છેલ્લા પાંચ વર્ષથી કેન્દ્રીય ગુપ્તચર વિભાગમાં આસિસ્ટન્ટ ડાયરેક્ટર તરીકે કામગીરી બજાવી રહ્યાં હતા . તેમની દિલ્હી BPRD ( બ્યૂરો ઓફ પોલીસ રિસર્ચ એન્ડ ડેવલોપમેન્ટ ) ખાતે એસપી તરીકે નિમણૂંક કરવામાં આવી છે .
#  Add-One: log-prob = -383.47090361172815 , prob = 2.8887009947103563e-167
#  Add-K  : log-prob = -363.25070894916456 , prob = 1.7467130137363e-158
#  Add-Type: log-prob = -440.20545432864526 , prob = 6.625219651138543e-192
# ------------------------------------------------------------
# Sentence: ૪.૦૦ લાખની વિશેષ ટેકનોલોજી ઇનોવેશન ગ્રાન્ટ આપવામાં આવનાર છે .
#  Add-One: log-prob = -89.65657187864706 , prob = 1.1551691091685877e-39
#  Add-K  : log-prob = -84.79208413760816 , prob = 1.4971515006734941e-37
#  Add-Type: log-prob = -103.81820603499023 , prob = 8.171955591678909e-46
# ------------------------------------------------------------
# Sentence: વન મેન શો અને ટૂ મેન આર્મી , તમારો ખેલ ખતમ થવાના આરે છે : શત્રુઘ્ન સિન્હા
#  Add-One: log-prob = -173.9529863923881 , prob = 2.8390817577581545e-76
#  Add-K  : log-prob = -166.59917503534018 , prob = 4.435040524836261e-73
#  Add-Type: log-prob = -197.51531525299092 , prob = 1.6603073643855807e-86
# ------------------------------------------------------------
# Sentence: ૧૭ એમએસયુ વડોદરા ફાર્મસી ૧૨
#  Add-One: log-prob = -59.367086300366694 , prob = 1.648929216382045e-26
#  Add-K  : log-prob = -57.06953049090382 , prob = 1.6406571026686733e-25
#  Add-Type: log-prob = -67.18173159862707 , prob = 6.658013662506126e-30
# ------------------------------------------------------------
# Sentence: લોકસાહિત્ય પરત્વે કેટલાક ગમા અણગમા કે પૂર્વગ્રહ શિક્ષિતવર્ગના હતા . તેમના મનમાં બાઝેલાં જાળાં તેમણે દૂર કરવાનો ભગીરથ પ્રયાસ કર્યો .
#  Add-One: log-prob = -199.50011556584403 , prob = 2.281395973392525e-87
#  Add-K  : log-prob = -190.0953470567715 , prob = 2.7710204939857312e-83
#  Add-Type: log-prob = -228.26924038382003 , prob = 7.310187444128212e-100
# ------------------------------------------------------------
# Sentence: સમય જતાં તે વધશે અને બદલાશે .
#  Add-One: log-prob = -69.74676085830119 , prob = 5.121139764412392e-31
#  Add-K  : log-prob = -66.43104752137359 , prob = 1.4104660412020884e-29
#  Add-Type: log-prob = -79.9450586627175 , prob = 1.9067869341278736e-35
# ------------------------------------------------------------
# Sentence: આ પહેલા સેમિફાઇનલમાં તેણે સ્પેનના પાબ્લો સામે 2 સેટમાં પાછળ રહ્યા બાદ ત્રણ સેટ જીતીને ફાઇનલમાં જગ્યા બનાવી હતી .
#  Add-One: log-prob = -181.6960271594738 , prob = 1.2314535098774024e-79
#  Add-K  : log-prob = -171.95883264306786 , prob = 2.0855848749674811e-75
#  Add-Type: log-prob = -209.3060011046091 , prob = 1.2576468026513877e-91
# ------------------------------------------------------------
# Sentence: પાલિકાની ઇજનેર શાખામાં અધિકારી અને કર્મચારીઓ દોડધામ કરતા નજરે ચડે છે .
#  Add-One: log-prob = -111.92245566005847 , prob = 2.4699894926667476e-49
#  Add-K  : log-prob = -106.53923359065631 , prob = 5.377726924017069e-47
#  Add-Type: log-prob = -128.69366601131267 , prob = 1.2854375887290555e-56
# ------------------------------------------------------------
# Sentence: ચાલુ વર્ષે એમ .
#  Add-One: log-prob = -37.17665206586929 , prob = 7.151302550645139e-17
#  Add-K  : log-prob = -34.7413044573443 , prob = 8.166635647094772e-16
#  Add-Type: log-prob = -43.44562538836677 , prob = 1.3545799124081923e-19
# ------------------------------------------------------------
# Sentence: સહિત પોલીસ સ્ટાફ ઇન્દ્રણજ દોડી ગયા હતા .
#  Add-One: log-prob = -70.72678410564167 , prob = 1.921975911005449e-31
#  Add-K  : log-prob = -66.41258782275995 , prob = 1.436744620331969e-29
#  Add-Type: log-prob = -82.33425434508794 , prob = 1.748588695220473e-36
# ------------------------------------------------------------
# Sentence: આ સિવાય સ્કિન સેલ્સને હાની કરનારા ફ્રી રેડિકલ્સને અસરને પણ ઓછી કરવામાં મદદ કરે છે .
#  Add-One: log-prob = -134.03803602225418 , prob = 6.137911049957561e-59
#  Add-K  : log-prob = -125.81488399260876 , prob = 2.2871262619470992e-55
#  Add-Type: log-prob = -156.14008520500832 , prob = 1.5460466410832682e-68
# ------------------------------------------------------------
# Sentence: ચિંતા દૂર થશે અને તમારા ઉત્સાહમાં વધારો થશે .
#  Add-One: log-prob = -80.78219336981051 , prob = 8.255420195172091e-36
#  Add-K  : log-prob = -75.7707065812147 , prob = 1.2393678950514455e-33
#  Add-Type: log-prob = -93.67102432357439 , prob = 2.0854079366473796e-41
# ------------------------------------------------------------
# Sentence: ( એજન્સી ) નવી દિલ્હી , તા . ૩
#  Add-One: log-prob = -80.20097107215068 , prob = 1.4762530914353163e-35
#  Add-K  : log-prob = -74.6810590369837 , prob = 3.6849207961190104e-33
#  Add-Type: log-prob = -93.03937477808898 , prob = 3.9220482679303185e-41
# ------------------------------------------------------------
# Sentence: મહત્વની શરતોનો સમાવેશ કરીને તમારી વેબસાઇટને શોધવાયોગ્ય બનાવો
#  Add-One: log-prob = -87.88904079098641 , prob = 6.765105360003486e-39
#  Add-K  : log-prob = -84.06890084768145 , prob = 3.0856045209823488e-37
#  Add-Type: log-prob = -99.71521529924671 , prob = 4.945750843573097e-44
# ------------------------------------------------------------
# Sentence: ભાવઘેલી બહેન ભાઇના જમ્યાં પછી જ જમે છે .
#  Add-One: log-prob = -81.56938966393652 , prob = 3.7571988153959883e-36
#  Add-K  : log-prob = -77.28537404747077 , prob = 2.725138123426997e-34
#  Add-Type: log-prob = -94.36895596597687 , prob = 1.0377271062712848e-41
# ------------------------------------------------------------
# Sentence: Ads વગર સમાચાર વાંચવા ઈન્સ્ટોલ કરો દિવ્ય ભાસ્કર એપમુંબઈ9 મિનિટ પહેલાકૉપી લિંકકંગના રનૌતે રવિવાર , 28 ફેબ્રુઆરીના રોજ સો .
#  Add-One: log-prob = -185.64631133642087 , prob = 2.3704532843929025e-81
#  Add-K  : log-prob = -174.83264383629785 , prob = 1.1780060620274276e-76
#  Add-Type: log-prob = -213.2388007850075 , prob = 2.4635733159271796e-93
# ------------------------------------------------------------
# Sentence: પાવર નૃત્યકારોને અપૂર્ણાંક હોવો જોઈએ , પરંતુ ઘણી વાર - તેઓ ઓછામાં ઓછી 5 વખત એક દિવસ ખાય છે .
#  Add-One: log-prob = -177.8450052178505 , prob = 5.792894241469662e-78
#  Add-K  : log-prob = -167.6015024030671 , prob = 1.627767404587594e-73
#  Add-Type: log-prob = -205.24274905696518 , prob = 7.314870364915055e-90
# ------------------------------------------------------------
# Sentence: ચેન્નાઈના ચાર નંબર પર આવેલા ખેલાડી અંબાતી રાયડુએ 33 બોલમાં 6 ચોક્કા અને 2 છક્કાની મદદથી અડધી સદી ફટકારી હતી અને ટીમને લક્ષ્ય પાછળ લઈ જવા સફળ રહ્યો હતો .
#  Add-One: log-prob = -279.80822524308013 , prob = 3.025741248202847e-122
#  Add-K  : log-prob = -265.4887798546268 , prob = 5.0082719361975144e-116
#  Add-Type: log-prob = -320.69599275985973 , prob = 5.290539678605604e-140
# ------------------------------------------------------------
# Sentence: મળતી માહિતી મુજબ બાપુનગરના મહેશ્વરી સોસાયટી પાસે સુરજીતસિંહ નામના શખ્સ દ્વારા ગેરકાયદે 4 દુકાનો બનાવાઈ .
#  Add-One: log-prob = -153.92864951204967 , prob = 1.4113570926339508e-67
#  Add-K  : log-prob = -146.2844343186036 , prob = 2.94765999342173e-64
#  Add-Type: log-prob = -176.254986385218 , prob = 2.8407433910242508e-77
# ------------------------------------------------------------
# Sentence: યુવરાજ સિંહની વિકેટ પડ્યાં બાદ વિરાટ કોહલીના રૂપમાં ભારતે ચોથી વિકેટ ગુમાવી છે .
#  Add-One: log-prob = -131.2462378884407 , prob = 1.001113031179866e-57
#  Add-K  : log-prob = -124.86507735930132 , prob = 5.912701037600699e-55
#  Add-Type: log-prob = -150.76202337469618 , prob = 3.348768823491011e-66
# ------------------------------------------------------------
# Sentence: '
#  Add-One: log-prob = -15.384026840436945 , prob = 2.0835409175103113e-07
#  Add-K  : log-prob = -14.290386315787565 , prob = 6.219623256180427e-07
#  Add-Type: log-prob = -17.838019774540488 , prob = 1.790797353248273e-08
# ------------------------------------------------------------
# Sentence: ખાંડ મિક્સ કરીને ખાવાથી દૂર રહો .
#  Add-One: log-prob = -68.8173154831342 , prob = 1.2972378933689872e-30
#  Add-K  : log-prob = -65.3155801080077 , prob = 4.3033233178925997e-29
#  Add-Type: log-prob = -79.10213856639324 , prob = 4.4297346701781715e-35
# ------------------------------------------------------------
# Sentence: ઈ-ધારા લેન્ડ રેકોર્ડઝ : વપરાશકર્તાઓ ( ગુજરાત રાજય ) તેમના જિલ્લા , તાલુકા અને ગામના સંદર્ભમાં ૭ ૧૨, ૮૧૨ અને ૬ ૧૨ ના તેમના જમીન રેકોર્ડ જોઈ શકે છે .
#  Add-One: log-prob = -283.56599025026406 , prob = 7.060820627906351e-124
#  Add-K  : log-prob = -270.4771276755592 , prob = 3.414097892274809e-118
#  Add-Type: log-prob = -324.21737507162965 , prob = 1.5638066990560027e-141
# ------------------------------------------------------------
# Sentence: જેમાં પોલીસે પત્નીની ધરપકડ કરી હત્યાની કોશિશનો ગુનો નોંધ્યો હતો .
#  Add-One: log-prob = -97.57999217014907 , prob = 4.183577863362998e-43
#  Add-K  : log-prob = -91.85731265902126 , prob = 1.279016036386531e-40
#  Add-Type: log-prob = -113.18316893652587 , prob = 7.001229056733654e-50
# ------------------------------------------------------------
# Sentence: આ સમજ કાં તો સાચી હોય છે , કાં તો ખોટી હોય છે .
#  Add-One: log-prob = -108.48665013394043 , prob = 7.67090292254902e-48
#  Add-K  : log-prob = -101.15750613955596 , prob = 1.169104360928148e-44
#  Add-Type: log-prob = -127.66594463324117 , prob = 3.592400257254407e-56
# ------------------------------------------------------------
# Sentence: જે માઁ ને આપણે બીજી માઁ કહીએ છીએ શુ એમાં મમતા , કરૂણા , ત્યાગ અને વાત્સલ્ય નથી જોવા મળતુ ?
#  Add-One: log-prob = -207.1107441239777 , prob = 1.129657224420745e-90
#  Add-K  : log-prob = -197.63095950493707 , prob = 1.4789886247917767e-86
#  Add-Type: log-prob = -236.04080086914465 , prob = 3.0816455051533694e-103
# ------------------------------------------------------------
# Sentence: આ મોડેલની એકમાત્ર ખામી એ ફ્રિઝરનો અભાવ છે .
#  Add-One: log-prob = -75.77564180026886 , prob = 1.2332664114638717e-33
#  Add-K  : log-prob = -71.3460304378586 , prob = 1.0346957735985616e-31
#  Add-Type: log-prob = -88.54664130987348 , prob = 3.5049537217146815e-39
# ------------------------------------------------------------
# Sentence: તમારી સાથે પણ એવું જ થાય છે .
#  Add-One: log-prob = -59.69955209682359 , prob = 1.18253486018535e-26
#  Add-K  : log-prob = -54.60002231812528 , prob = 1.9387043976915573e-24
#  Add-Type: log-prob = -71.10265932432198 , prob = 1.319797820386752e-31
# ------------------------------------------------------------
# Sentence: યુ .
#  Add-One: log-prob = -18.604964843364062 , prob = 8.316994849248553e-09
#  Add-K  : log-prob = -17.11311493474447 , prob = 3.697163149449628e-08
#  Add-Type: log-prob = -22.198763403645092 , prob = 2.2866492268425613e-10
# ------------------------------------------------------------
# Sentence: હવે આ શૉ કોણ જીતશે તે સમય જ જણાવશે .
#  Add-One: log-prob = -93.3246688319403 , prob = 2.948569038040296e-41
#  Add-K  : log-prob = -88.25382237781234 , prob = 4.697339332510874e-39
#  Add-Type: log-prob = -107.5397599084031 , prob = 1.977314206106042e-47
# ------------------------------------------------------------
# Sentence: આ વિવાદ પૂર્ણ કરવા માટે નાણાં મંત્રી અરુણ જેટલી જાતે સામે આવ્યા હતા અને તેમણે પીએમ મોદીનો બચાવ કરતાં કહ્યું હતું કે , પીએમ મોદીએ પૂર્વ પીએમ અને પૂર્વ ઉપરાષ્ટ્રપતિ અંગે કોઇ પણ પ્રકારની ટિપ્પણી નથી કરી .
#  Add-One: log-prob = -328.93260771450696 , prob = 1.4008239281825858e-143
#  Add-K  : log-prob = -309.04544832400694 , prob = 6.071096493489317e-135
#  Add-Type: log-prob = -380.25759184634677 , prob = 7.181681807539977e-166
# ------------------------------------------------------------
# Sentence: જો કે , ત્યાં ઘણા ફંડ દુકાનો નથી જે ડેટ-તે-જાતે રોકાણકાર માટે ઓછા ન્યૂનતમ અને ઉચ્ચ ગુણવત્તાની નો-લોડ ફંડ છે .
#  Add-One: log-prob = -183.81075419921368 , prob = 1.4859484278003524e-80
#  Add-K  : log-prob = -173.5612171404161 , prob = 4.200694745191131e-76
#  Add-Type: log-prob = -212.43110764052645 , prob = 5.5251257532819075e-93
# ------------------------------------------------------------
# Sentence: બીજી બાજુ ઓટો કંપનીઓના શેર તેજીમાં રહી શકે છે .
#  Add-One: log-prob = -81.32196231600489 , prob = 4.8119433807450896e-36
#  Add-K  : log-prob = -75.89086344109349 , prob = 1.0990483046266435e-33
#  Add-Type: log-prob = -95.46784758923562 , prob = 3.458124245589586e-42
# ------------------------------------------------------------
# Sentence: પ્રધાનમંત્રી નરેન્દ્રભાઈ મોદીના વરદ હસ્તે રૂ . ૧૧૮ કરોડના લાઈટ હાઉસ પ્રોજેક્ટનું 1 જાન્યુઆરીએ ઈ-ખાતમુહૂર્ત રાજકોટ મહાનગરપાલિકા દ્વારા રૈયા સ્માર્ટ સિટી એરિયા ખાતે રૂ .
#  Add-One: log-prob = -235.5018520395419 , prob = 5.282569033939924e-103
#  Add-K  : log-prob = -223.34566095600752 , prob = 1.005106056113967e-97
#  Add-Type: log-prob = -269.67948445754496 , prob = 7.58032834313521e-118
# ------------------------------------------------------------
# Sentence: ૧૬ થી ૧૮ ફેબ્રુઆરીમાં મધ્યપ્રદેશમાં કમોસમી વરસાદની શક્યતા છે .
#  Add-One: log-prob = -89.6592420895207 , prob = 1.152088678582305e-39
#  Add-K  : log-prob = -84.73855698886902 , prob = 1.5794733234980022e-37
#  Add-Type: log-prob = -103.81890812555008 , prob = 8.166220152436907e-46
# ------------------------------------------------------------
# Sentence: ધ .
#  Add-One: log-prob = -20.88280329443725 , prob = 8.525380328627786e-10
#  Add-K  : log-prob = -19.686505118994514 , prob = 2.8200672098661902e-09
#  Add-Type: log-prob = -24.476180380972334 , prob = 2.3449302139883248e-11
# ------------------------------------------------------------
# Sentence: કોંગ્રેસે પ્રતિક્રિયા આપતાં કહ્યું કે , ભાજપના પ્રદેશ પ્રમુખ અને પ્રવકતા થોડા દિવસ પહેલાં દલીલ કરતાં હતા કે , અમે ચેકના નાણાં ભરી દીધા છે , તો પછી શા માટે કોર્ટને ના સમજાવી શક્યા ?
#  Add-One: log-prob = -309.1083278890058 , prob = 5.70110300170083e-135
#  Add-K  : log-prob = -291.1465834840164 , prob = 3.6028432529543343e-127
#  Add-Type: log-prob = -356.4086358964482 , prob = 1.6356716541314866e-155
# ------------------------------------------------------------
# Sentence: પંચામૃત પ્રસાદ બનાવવાની રીત :
#  Add-One: log-prob = -54.63564172317695 , prob = 1.8708642851796477e-24
#  Add-K  : log-prob = -51.83984472074726 , prob = 3.0636665514970953e-23
#  Add-Type: log-prob = -62.44035288654174 , prob = 7.629556496213305e-28
# ------------------------------------------------------------
# Sentence: સમગ્ર રાજયમાં એકતા યાત્રાનું પરિભ્રમણ થવાનું છે ત્યારે આ રથયાત્રામાં જનજન જોડાય અને સરદાર પટેલના એકતા-અખંડિતતાના સંદેશાને પહોંચાડી દેશના એકસૂત્રતાના તાંતણે બાંધવા જન જનને સંકલ્પબધ્ધ થવા આઇ .
#  Add-One: log-prob = -266.766692281987 , prob = 1.3953963619168986e-116
#  Add-K  : log-prob = -253.96350253359714 , prob = 5.0705170200340455e-111
#  Add-Type: log-prob = -304.9203270132641 , prob = 3.7565100753855864e-133
# ------------------------------------------------------------
# Sentence: ચોથા ક્રમાંકિત સિંધુએ 355,000 યુએસ ટુર્નામેન્ટના બીજા રાઉન્ડમાં વિશ્વ ક્રમાંક 22 ડેનમાર્ક મિયા બ્લિફેલ્ડને 21 - 13, 21 - 19 થી હરાવ્યો હતો .
#  Add-One: log-prob = -228.02587274325947 , prob = 9.324418050646662e-100
#  Add-K  : log-prob = -216.6335829068894 , prob = 8.264761940616308e-95
#  Add-Type: log-prob = -261.0458285635037 , prob = 4.258308594174291e-114
# ------------------------------------------------------------
# Sentence: જેમ કે - " અણુ " મિશ્રણ અન્ય આત્માઓ સાથે .
#  Add-One: log-prob = -104.8867723847518 , prob = 2.8070718477534257e-46
#  Add-K  : log-prob = -99.49036489142014 , prob = 6.192749673854847e-44
#  Add-Type: log-prob = -120.44773767486191 , prob = 4.900181542021976e-53
# ------------------------------------------------------------
# Sentence: ફિલ્મ ગોલમાલના ત્રણ ભાગ બોકસ ઓફિસ પર સફળ રહ્યાં હોવાથી દરેક સિતારા રોહિત સાથે ફિલ્મ કરવા ખૂબ જ ઉત્સાહમાં અને આતુર હોય છે .
#  Add-One: log-prob = -220.18351803721598 , prob = 2.374177092820144e-96
#  Add-K  : log-prob = -209.17675334276447 , prob = 1.4311668916910142e-91
#  Add-Type: log-prob = -252.93351021266736 , prob = 1.4202742924798542e-110
# ------------------------------------------------------------
# Sentence: તેને અડધો કલાક માટે રાખી દો પછી તેને શેમ્પુથી ધોઈ લો .
#  Add-One: log-prob = -112.75687632412561 , prob = 1.07228644443223e-49
#  Add-K  : log-prob = -106.59335580346122 , prob = 5.094408507813301e-47
#  Add-Type: log-prob = -129.69511580405387 , prob = 4.722009717618794e-57
# ------------------------------------------------------------
# Sentence: પાંચમાં દિવસે રામકથાના વિરામ બાદ મોરારીબાપુએ કથા સ્થળે ચાલી રહેલા ભોજન-પ્રસાદના પંડાલે રામકથાના આયોજક પરિવારના જયંતિભાઇ ચાંદ્રા અને અગ્રણી કાર્યકરો સાથે મુલાકાત લીધી હતી .
#  Add-One: log-prob = -235.22131173710886 , prob = 6.993302052068051e-103
#  Add-K  : log-prob = -223.35773712904543 , prob = 9.930412166251349e-98
#  Add-Type: log-prob = -269.50065595718223 , prob = 9.064675224167224e-118
# ------------------------------------------------------------
# Sentence: અમદાવાદમાં આવેલા કાંકરિયા લેક્ફ્રન્ટમાં પ્રથમ દિવસે જ મોટી સંખ્યામાં શહેરીજનો ઉમટી પડ્યા
#  Add-One: log-prob = -120.36800755976512 , prob = 5.306870856116663e-53
#  Add-K  : log-prob = -114.10806207266349 , prob = 2.7765039852223517e-50
#  Add-Type: log-prob = -137.52824961697604 , prob = 1.871716571850587e-60
# ------------------------------------------------------------
# Sentence: પાનખર-શિયાળાની સીઝન 2016 - 2017 માં લેધર જેકેટ પ્રચલિત રહેશે .
#  Add-One: log-prob = -105.69248576623315 , prob = 1.254112951966585e-46
#  Add-K  : log-prob = -100.48636623994588 , prob = 2.2873131957941657e-44
#  Add-Type: log-prob = -121.32172257937233 , prob = 2.044774162297431e-53
# ------------------------------------------------------------
# Sentence: પોલીસ જવાનોએ ઘોષણા કરી છે કે દિલ્હી પોલીસ હેડક્વાર્ટરના કાર્યક્રમ પછી પણ કોઈ પોલીસ જવાન ઘેર નહીં જાય .
#  Add-One: log-prob = -170.570766435382 , prob = 8.357133948340695e-75
#  Add-K  : log-prob = -160.9441297856541 , prob = 1.267221519584403e-70
#  Add-Type: log-prob = -196.6589243179594 , prob = 3.9094381949923495e-86
# ------------------------------------------------------------
# Sentence: પરંતુ કેટલાક ભાગોમાં , પૂર્વ ભારતના મોટાભાગના લોકો ફક્ત આંશિક ચંદ્રગ્રહણની અંતિમ ક્ષણો જોઈ શકશે .
#  Add-One: log-prob = -147.83046757069218 , prob = 6.281215256375771e-65
#  Add-K  : log-prob = -139.54535370340014 , prob = 2.490135107977842e-61
#  Add-Type: log-prob = -170.05179202127613 , prob = 1.4042521174039571e-74
# ------------------------------------------------------------
# Sentence: નવી દિલ્હી : તાઇવાને એક વર્ષમાં અનેક વખત ચીન દ્વારા તેના હવાઈક્ષેત્રમાં અતિક્રમણની ફરિયાદ કરી છે .
#  Add-One: log-prob = -142.6123412322138 , prob = 1.159436989500458e-62
#  Add-K  : log-prob = -132.87433740651443 , prob = 1.9652077936603756e-58
#  Add-Type: log-prob = -166.06850799845745 , prob = 7.539861326258924e-73
# ------------------------------------------------------------
# Sentence: ૭. તેને ટામેટાની ચટણી અને ચા સાથે ખાવાની મજા લો .
#  Add-One: log-prob = -106.94444093699448 , prob = 3.586075516729341e-47
#  Add-K  : log-prob = -101.74333309972161 , prob = 6.507765037155597e-45
#  Add-Type: log-prob = -122.4996327432578 , prob = 6.296300750138755e-54
# ------------------------------------------------------------
# Sentence: પરંતુ થોડા સમય પછી મારા ઉપર જ હાવી થઇ ગઇ હતી .
#  Add-One: log-prob = -101.97476255847472 , prob = 5.163252065670675e-45
#  Add-K  : log-prob = -95.22547686423282 , prob = 4.406571905675315e-42
#  Add-Type: log-prob = -118.89560032204568 , prob = 2.3136457187202118e-52
# ------------------------------------------------------------
# Sentence: આ વિસ્તારમાં રોજ વારાફરતી ગ્રામજનો એક ઘરે ભેગા બેસી સુરક્ષા કરે છે .
#  Add-One: log-prob = -109.0965146860208 , prob = 4.168556353602367e-48
#  Add-K  : log-prob = -102.56223508078737 , prob = 2.869374621022536e-45
#  Add-Type: log-prob = -127.19805865252813 , prob = 5.735681384609919e-56
# ------------------------------------------------------------
# Sentence: હું જવાબ પર અડગ રહી .
#  Add-One: log-prob = -56.41011638472142 , prob = 3.172471509565652e-25
#  Add-K  : log-prob = -53.17431160145037 , prob = 8.066588306738976e-24
#  Add-Type: log-prob = -65.32715497343523 , prob = 4.253800094833323e-29
# ------------------------------------------------------------
# Sentence: એમ .
#  Add-One: log-prob = -16.44749064493871 , prob = 7.193588182194789e-08
#  Add-K  : log-prob = -14.870249144797985 , prob = 3.482834612893202e-07
#  Add-Type: log-prob = -20.03980623211297 , prob = 1.9807183953461715e-09
# ------------------------------------------------------------
# Sentence: ખાસ કરીને ફર્સ્ટ ટાઇમ સેક્સ દરેક લોકો માટે અલગ અલગ અનુભવ હોય છે .
#  Add-One: log-prob = -114.0469962239136 , prob = 2.9513374066095454e-50
#  Add-K  : log-prob = -106.20330974806663 , prob = 7.524690066822603e-47
#  Add-Type: log-prob = -133.50882132893338 , prob = 1.0419709508934054e-58
# ------------------------------------------------------------
# Sentence: ઔષધનો " આઇઆરએસ 19 " ચિલ્ડ્રન્સ માર્ગદર્શિકા ત્રણ મહિનાની ઉંમરથી સાથે ઉપયોગ કરવા માટે પરવાનગી આપે છે .
#  Add-One: log-prob = -157.89089138192045 , prob = 2.6844611925799567e-69
#  Add-K  : log-prob = -148.83979571172299 , prob = 2.289275364765607e-65
#  Add-Type: log-prob = -182.69150661268415 , prob = 4.550789920699448e-80
# ------------------------------------------------------------
# Sentence: તેમજ પોર્ટફોલિયો રિશફલિંગનો પણ છે .
#  Add-One: log-prob = -48.34679451284279 , prob = 1.0075205785925782e-21
#  Add-K  : log-prob = -45.07226949690206 , prob = 2.66294422710367e-20
#  Add-Type: log-prob = -57.118478569937736 , prob = 1.5622838466477978e-25
# ------------------------------------------------------------
# Sentence: હું રમતમાં ખૂબ જ સક્રિય હોવાથી મારા ગામમાં એક રમતગમત શિક્ષકે મને મારા માતાપિતાને 2008 માં અકોલામાં બોક્સીંગ એકેડેમીમાં મોકલવાની સલાહ આપી તેના માતાપિતા સંમત થયા .
#  Add-One: log-prob = -258.9718542708405 , prob = 3.3880727096212034e-113
#  Add-K  : log-prob = -246.64471484782024 , prob = 7.648237243015117e-108
#  Add-Type: log-prob = -295.97577485836837 , prob = 2.879746121091807e-129
# ------------------------------------------------------------
# Sentence: રામલાના તું
#  Add-One: log-prob = -30.042155235200415 , prob = 8.971349105534197e-14
#  Add-K  : log-prob = -29.064369505346733 , prob = 2.385089628160871e-13
#  Add-Type: log-prob = -33.83940563715021 , prob = 2.0124859677918368e-15
# ------------------------------------------------------------
# Sentence: મને હજુ સુધી સમજમાં નથી આવ્યું કે કેટલાક લોકો સેના પર કેમ સવાલ કરી રહ્યા છે .
#  Add-One: log-prob = -142.6300157819435 , prob = 1.1391244986178478e-62
#  Add-K  : log-prob = -133.17719202093306 , prob = 1.451711743191893e-58
#  Add-Type: log-prob = -166.04298287517943 , prob = 7.734794478836773e-73
# ------------------------------------------------------------
# Sentence: ઉદ્યોગ જગતના પિતામહ ગણાતા અને ખેડૂતોને પીઠબળ બની રહેવાના ઉદ્યોગ મંત્ર સ્વરૂપે તેમણે એકસેલ ક્રોપ કેર લી .
#  Add-One: log-prob = -178.72870650590227 , prob = 2.393916547805611e-78
#  Add-K  : log-prob = -170.93141529938381 , prob = 5.82679248679465e-75
#  Add-Type: log-prob = -203.6791536941417 , prob = 3.493554091390217e-89
# ------------------------------------------------------------
# Sentence: ધ્રુવરાજસિંહ લૂંટ કરવા માટે જતો ત્યારે એક બાઇકમાં ત્રણ સવારીમાં જતો હતો .
#  Add-One: log-prob = -118.89277329123492 , prob = 2.3201957206184564e-52
#  Add-K  : log-prob = -112.61633899719607 , prob = 1.2340859313835953e-49
#  Add-Type: log-prob = -137.13387423026947 , prob = 2.7766116388505114e-60
# ------------------------------------------------------------
# Sentence: મી લાંબી ગટર નાખવામાં આવશે .
#  Add-One: log-prob = -54.67242936680959 , prob = 1.803290163595926e-24
#  Add-K  : log-prob = -51.37172093377915 , prob = 4.8926604022428387e-23
#  Add-Type: log-prob = -63.619786162033975 , prob = 2.3457295020142246e-28
# ------------------------------------------------------------
# Sentence: સુરત મહાનગરપાલિકા અને જિલ્લા પ્રશાસને જાહેર કરેલા આંકડા પ્રમાણે પોઝિટિવ કેસનો આંક 143326 પર પહોચી ગયો છે .
#  Add-One: log-prob = -163.39980841971035 , prob = 1.0873387344969516e-71
#  Add-K  : log-prob = -154.50219466221395 , prob = 7.953337575479371e-68
#  Add-Type: log-prob = -188.1798253948508 , prob = 1.8816559820807663e-82
# ------------------------------------------------------------
# Sentence: હાયપોકોન્ડા્રિયા - તે પરિવારોમાં વિકાસ થયો છે જ્યાં બાળક ગંભીર બીમારી સાથે લાંબા સમયથી બીમાર છે .
#  Add-One: log-prob = -151.6618577083856 , prob = 1.3617333757754396e-66
#  Add-K  : log-prob = -143.2345584722768 , prob = 6.223312905042158e-63
#  Add-Type: log-prob = -175.00029221676604 , prob = 9.961821573455011e-77
# ------------------------------------------------------------
# Sentence: અને તે તેને ભૂલીને આગળ વધી ગઇ છે .
#  Add-One: log-prob = -70.02373937519974 , prob = 3.882186429253308e-31
#  Add-K  : log-prob = -64.80259711448093 , prob = 7.187695331756445e-29
#  Add-Type: log-prob = -82.75248705693907 , prob = 1.1509368821646272e-36
# ------------------------------------------------------------
# Sentence: આ એન્જીન 120 કિમી પ્રતિ કલાકની ગતિથી સફર કરી શકે છે .
#  Add-One: log-prob = -96.72426452175796 , prob = 9.844318403985909e-43
#  Add-K  : log-prob = -90.54213808719248 , prob = 4.764847977307163e-40
#  Add-Type: log-prob = -113.49099790034268 , prob = 5.146190588212525e-50
# ------------------------------------------------------------
# Sentence: જણાવી કે ખેડૂત કેન્દ્ર સરકારને લાગુ કૃષિ કાયદાઓ વિરુદ્ધ આંદોલન કરી રહ્યા છે .
#  Add-One: log-prob = -121.16911396430595 , prob = 2.381893987745992e-53
#  Add-K  : log-prob = -114.09163866629032 , prob = 2.8224801476499382e-50
#  Add-Type: log-prob = -140.61866336007077 , prob = 8.51315322395568e-62
# ------------------------------------------------------------
# Sentence: .
#  Add-One: log-prob = -6.251611601542329 , prob = 0.0019273455189633814
#  Add-K  : log-prob = -5.3273687919138935 , prob = 0.004856832551519934
#  Add-Type: log-prob = -8.50610138648829 , prob = 0.0002022307094124616
# ------------------------------------------------------------
# Sentence: સાઇકલ પર આગળના ભાગ પર પતરાની બનાવેલી બત્તી લગાવવામાં આવતી હતી , જેમાં એક નાનકડો બલ્બ રહેતો , જે સેલ દ્વારા ચાલતો હતો .
#  Add-One: log-prob = -217.25498085788706 , prob = 4.439771790322987e-95
#  Add-K  : log-prob = -205.463127902758 , prob = 5.8680974473132106e-90
#  Add-Type: log-prob = -249.97369104353186 , prob = 2.7403457342390557e-109
# ------------------------------------------------------------
# Sentence: એક ફર કોટ માટે સિલ્ક બેલ્ટ
#  Add-One: log-prob = -65.14677883445219 , prob = 5.094639264864715e-29
#  Add-K  : log-prob = -62.23183373070216 , prob = 9.398488449782643e-28
#  Add-Type: log-prob = -74.24604576223027 , prob = 5.693142079721162e-33
# ------------------------------------------------------------
# Sentence: મુખ્યમંત્રી શ્રી ભૂપેન્દ્રભાઇ પટેલે જણાવ્યું કે , ગુજરાતમાં એર , રેલ અને રોડ કનેક્ટિવિટીનું સુદ્રઢ માળખું ઉભુ કરવામાં આવ્યું છે .
#  Add-One: log-prob = -180.91581365103198 , prob = 2.686955304449038e-79
#  Add-K  : log-prob = -170.36492324563923 , prob = 1.0267244979675826e-74
#  Add-Type: log-prob = -209.4763022357453 , prob = 1.0607128973244292e-91
# ------------------------------------------------------------
# Sentence: પરંતુ શું તમે જાણો છો કે કેટલીકવાર તમારું ઘર એટલી ગંદું નથી હોતું કારણ કે કેટલીક ભૂલોને લીધે તે દેખાય છે .
#  Add-One: log-prob = -195.13694927046728 , prob = 1.791017034188918e-85
#  Add-K  : log-prob = -184.05518020680958 , prob = 1.1637263564535495e-80
#  Add-Type: log-prob = -225.23487937341082 , prob = 1.519619143546484e-98
# ------------------------------------------------------------
# Sentence: સો ગુણોથી ભરપૂર હોય છે ગાયનું ઘી , દરરોજ 2 ચમચી ઉપયોગમાં લેશો તો કોલેસ્ટ્રોલ , માઇગ્રેન અને કફ જેવી સમસ્યા થશે છૂમંતર
#  Add-One: log-prob = -231.26913001303956 , prob = 3.6399297403439705e-101
#  Add-K  : log-prob = -221.4167009640872 , prob = 6.917490479148933e-97
#  Add-Type: log-prob = -262.74344279362134 , prob = 7.79780981014045e-115
# ------------------------------------------------------------
# Sentence: પોલીસે જણાવ્યું કે તે વ્યક્તિએ પોતાને એક બેંક કર્મચારી ગણાવ્યો હતો અને મહિલા સાથે લગ્ન કરવાનું પણ કહ્યું હતું .
#  Add-One: log-prob = -170.2952802421471 , prob = 1.1007773801302502e-74
#  Add-K  : log-prob = -159.19590750961993 , prob = 7.279404067246562e-70
#  Add-Type: log-prob = -197.75108000967603 , prob = 1.3115871750064604e-86
# ------------------------------------------------------------
# Sentence: રામમંદિર માટે જમીન કૌભાંડના આક્ષેપો કરનાર આમઆદમી પાર્ટીના સાંસદ સંજયસિંહના સરકારી નિવાસ પર ૪ - ૫ લોકો દ્વારા હુમલો કરીને તોડફોડ કરાઈ હતી .
#  Add-One: log-prob = -226.3186225884632 , prob = 5.141277646554072e-99
#  Add-K  : log-prob = -214.9780517540066 , prob = 4.327313832208615e-94
#  Add-Type: log-prob = -259.2668707648135 , prob = 2.5224855467924796e-113
# ------------------------------------------------------------
# Sentence: અર્થતંત્રમાં મડાગાંઠ
#  Add-One: log-prob = -30.04190677626586 , prob = 8.973578394306355e-14
#  Add-K  : log-prob = -29.063872687456524 , prob = 2.386274877760117e-13
#  Add-Type: log-prob = -33.83934054489167 , prob = 2.0126169693123023e-15
# ------------------------------------------------------------
# Sentence: પરંતુ હવે થોડી હળવાશની વાત એ છે કે , લંડનમાં પ્રકાશિત જર્નલ ફિજીક્સ ઓફ ફ્લ્યૂડ્સ માં છપાયેલા એક અધ્યયન મુજબ હવામાં રહેલા અતિસૂક્ષ્મ ડ્રોપ્લેટ્સથી કોરોના વાયરસના ફેલાવાની શક્યતા નહીંવત્ છે .
#  Add-One: log-prob = -275.9445254809844 , prob = 1.4415020760566656e-120
#  Add-K  : log-prob = -261.5511021658653 , prob = 2.5692099403938085e-114
#  Add-Type: log-prob = -317.88373752147197 , prob = 8.80738350808208e-139
# ------------------------------------------------------------
# Sentence: મંત્રાલયે એમ પણ જણાવ્યું કે , હાલ હજ યાત્રીઓને એકત્રિત કરવા તથા યાત્રાના સમય સહિત અન્ય વ્યવસ્થાઓ પર વિચારણા કરવાની જરૂર હશે .
#  Add-One: log-prob = -207.25482811499253 , prob = 9.780741972380736e-91
#  Add-K  : log-prob = -195.68093936912146 , prob = 1.0395558299844417e-85
#  Add-Type: log-prob = -238.74496519019354 , prob = 2.0624291377609077e-104
# ------------------------------------------------------------
# Sentence: શિશુમાં હિપ સાંધાના ડિસપ્લેસિયાને નીચેની પદ્ધતિઓ દ્વારા દૂર કરવામાં આવે છે :
#  Add-One: log-prob = -111.86674990246894 , prob = 2.6114866431128423e-49
#  Add-K  : log-prob = -105.69844587438601 , prob = 1.246660533807013e-46
#  Add-Type: log-prob = -128.87032765911522 , prob = 1.0772780638457227e-56
# ------------------------------------------------------------
# Sentence: ભારતીય હવામાન વિભાગ આગામી મહિને મોનસૂનનું પહેલું અનુમાન જાહેર કરશે .
#  Add-One: log-prob = -103.37729874484724 , prob = 1.27001719517259e-45
#  Add-K  : log-prob = -97.84701860319943 , prob = 3.2031682417291973e-43
#  Add-Type: log-prob = -119.01801288256162 , prob = 2.0470750166568747e-52
# ------------------------------------------------------------
# Sentence: કાશ્મીરના મુદ્દાનુ શાંતિપુર્વક સમાધાન ઈચ્છે છે પાક : ગિલાની
#  Add-One: log-prob = -98.52591725295436 , prob = 1.6245676937772542e-43
#  Add-K  : log-prob = -94.69139275154303 , prob = 7.517105479370882e-42
#  Add-Type: log-prob = -111.5450714684078 , prob = 3.602392068587416e-49
# ------------------------------------------------------------
# Average log-prob (Add-One) over sample: -142.8563075699382
# Average log-prob (Add-K k=0.5) over sample: -135.20549696959523
# Average log-prob (Add-Type) over sample: -164.4891147712969

# %%
# Q3: Smoothed Language Models on 1000 sentences

import pandas as pd
import random
import math
from collections import Counter, defaultdict

# ------------------------------
# Step 1: Load dataset
# ------------------------------
file_path = "/content/tokenized_gujarati_sentences.parquet"
df = pd.read_parquet(file_path)

# Assume the column with sentences is "sentence"
sentences = df["sentence"].dropna().tolist()

# ------------------------------
# Step 2: Randomly sample 1000 sentences
# ------------------------------
sampled_sentences = random.sample(sentences, min(1000, len(sentences)))

print(f"Total sampled sentences: {len(sampled_sentences)}")

# ------------------------------
# Step 3: Tokenization (basic whitespace split)
# ------------------------------
tokenized_sentences = [["<s>"] + s.split() + ["</s>"] for s in sampled_sentences]

# ------------------------------
# Step 4: Build Unigram & Bigram counts
# ------------------------------
unigram_counts = Counter()
bigram_counts = Counter()

for sent in tokenized_sentences:
    unigram_counts.update(sent)
    bigram_counts.update([(sent[i], sent[i+1]) for i in range(len(sent)-1)])

V = len(unigram_counts)   # Vocabulary size
print("Vocabulary size:", V)

# ------------------------------
# Step 5: Laplace Smoothed Bigram Probability
# ------------------------------
def bigram_prob(w1, w2):
    # (count(w1,w2) + 1) / (count(w1) + V)
    return (bigram_counts[(w1, w2)] + 1) / (unigram_counts[w1] + V)

# ------------------------------
# Step 6: Compute Sentence Probability
# ------------------------------
def sentence_probability(sentence):
    words = ["<s>"] + sentence.split() + ["</s>"]
    prob_log = 0.0
    for i in range(len(words)-1):
        prob = bigram_prob(words[i], words[i+1])
        prob_log += math.log(prob)  # log probability
    return math.exp(prob_log)       # return actual probability

# ------------------------------
# Step 7: Example Output
# ------------------------------
# Print probabilities for ALL 1000 sentences
results = []
for s in sampled_sentences:
    p = sentence_probability(s)
    results.append((s, p))

# Show first 10 for sanity check
for i in range(10):
    print(f"Sentence: {results[i][0]}")
    print(f"Probability: {results[i][1]:.10e}\n")

# Save all results to CSV
pd.DataFrame(results, columns=["sentence", "probability"]).to_csv("sentence_probabilities.csv", index=False)
print("✅ Saved all 1000 sentence probabilities to sentence_probabilities.csv")
# Out:
# Total sampled sentences: 1000
# Vocabulary size: 6278
# Sentence: બોટાદના હડદડ ગામે આવેલ પ્રાથમિક શાળામાં વારંવારની નેતાઓ તથા ધારાસભ્યો પાસે માંગણી કરવા છતાં ધોરણ 9 10 મંજૂરી મળી નથી રહી .
# Probability: 2.3716557078e-78
#
# Sentence: નવરાત્રી નજીક આવતાની સાથે જ કુંભાર સવારે વહેલા ઉઠી ચાકડા ઉપર માટીનો પીંડો ચડાવી ગરબા બનાવવા લાગી જાય છે .
# Probability: 6.4402904172e-68
#
# Sentence: જો પૃષ્ઠભૂમિની તપાસ તમારા ભૂતકાળમાં વર્તણૂકો છતી કરે છે જે છેવટે અયોગ્યતાના અર્થમાં હશે , તો તમારું પહેલું પગલું એ શોધવાનું છે કે તે શું છે જે તમને ભાડે લેવાથી રાખવામાં આવે છે .
# Probability: 4.2076058187e-111
#
# Sentence: ગ્રાહક કલ્યાણ ભંડોળમાં 16.58 કરોડ રૂપિયા જમા
# Probability: 1.8241338270e-28
#
# Sentence: કોર્ટે મંગળવારે સુષ્મિતાને ચૂંટણી પંચના નિર્ણયનો રેકોર્ડ દાખલ કરવાની મંજૂરી આપી હતી .
# Probability: 7.0518342874e-45
#
# Sentence: હવે પૂરી બનાવવા માટે મેંદાના લોટને એક બાઉલમાં લઇ તેમાં ઘઉંનો લોટ , નમક અને તેલ ઉમેરી મિક્ષ કરી લો .
# Probability: 9.8898727277e-74
#
# Sentence: આ રાશિના લોકો પર માં કાળીની કૃપા દૃષ્ટિ બની છે , જેના કારણે તમારા જીવનમાં આવનાર દરેક સમસ્યાઓ સમાપ્ત થશે .
# Probability: 4.7107824066e-70
#
# Sentence: મધ્ય પ્રદેશ મધ્ય પ્રદેશમાં આજે શિવ રાજ માટે થઈ શકે છે મંત્રી મંડળનો વિસ્તાર , 5 મંત્રી .
# Probability: 5.2978158373e-63
#
# Sentence: યુરોપિયન યુનિયનના બંધારણની ૫૦ મી કલમ ( આર્ટિકલ ૫૦ ) નો ખરેખર કેવો અને કેટલો અસરકારક અમલ થાય છે તે માત્ર અટકળોનો વિષય છે .
# Probability: 4.0575374419e-85
#
# Sentence: આ એપ ટચમાં આવતા સોફ્ટવેર પ્રોબ્લેમને સોલ્વ કરી નાખે છે .
# Probability: 2.0639822504e-36
#
# ✅ Saved all 1000 sentence probabilities to sentence_probabilities.csv
